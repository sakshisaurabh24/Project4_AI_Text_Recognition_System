# %%
# =====================================
# Project 4 - AI Text Recognition System
# =====================================

print("===== AI TEXT RECOGNITION SYSTEM =====")

text = input("Enter any text: ")

print("\nText Recognized Successfully!")

print("\nYou Entered:")
print(text)

print("\nAnalysis")
print("----------------------")
print("Total Words      :", len(text.split()))
print("Total Characters :", len(text))
print("Uppercase        :", text.upper())
print("Lowercase        :", text.lower())
# Out:
# ===== AI TEXT RECOGNITION SYSTEM =====
# Enter any text: Python is my favorite programming language
#
# Text Recognized Successfully!
#
# You Entered:
# Python is my favorite programming language
#
# Analysis
# ----------------------
# Total Words      : 6
# Total Characters : 42
# Uppercase        : PYTHON IS MY FAVORITE PROGRAMMING LANGUAGE
# Lowercase        : python is my favorite programming language

# %%
print("\n===== PROJECT COMPLETED =====")
print("Project Name : AI Text Recognition System")
print("Concept      : Basic Text Recognition")
print("Language     : Python")
print("Status       : Successfully Completed")
# Out:
# ===== PROJECT COMPLETED =====
# Project Name : AI Text Recognition System
# Concept      : Basic Text Recognition
# Language     : Python
# Status       : Successfully Completed
